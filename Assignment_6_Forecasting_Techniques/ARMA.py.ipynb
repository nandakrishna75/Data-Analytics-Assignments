# %%
# ARMA example
from statsmodels.tsa.arima_model import ARMA
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
from random import random
# contrived dataset
data = [random() for x in range(1, 100)]
# fit model
# make prediction
size = int(len(data) * 0.66)
train, test = data[0:size], data[size:len(data)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color="red")
pyplot.show()
# Out:
# predicted=0.550914, expected=0.566675
# predicted=0.588809, expected=0.388694
# predicted=0.516108, expected=0.974258
# predicted=0.460827, expected=0.746662
# predicted=0.460525, expected=0.749789
# predicted=0.555853, expected=0.733774
# predicted=0.528942, expected=0.286793
# predicted=0.645313, expected=0.739208
# predicted=0.460672, expected=0.514943
# predicted=0.583678, expected=0.633420
# predicted=0.474139, expected=0.693451
# predicted=0.517826, expected=0.695012
# predicted=0.551932, expected=0.005877
# predicted=0.563046, expected=0.053135
# predicted=0.539843, expected=0.796950
# predicted=0.460466, expected=0.935796
# predicted=0.471104, expected=0.724875
# predicted=0.402121, expected=0.187679
# predicted=0.536605, expected=0.427783
# predicted=0.562448, expected=0.596096
# predicted=0.561815, expected=0.306918
# predicted=0.490787, expected=0.382384
# predicted=0.465911, expected=0.604404
# predicted=0.534337, expected=0.086884
# predicted=0.493299, expected=0.915021
# predicted=0.464686, expected=0.834371
# predicted=0.486689, expected=0.752088
# predicted=0.486276, expected=0.927944
# predicted=0.469879, expected=0.018691
# predicted=0.609294, expected=0.793361
# predicted=0.458165, expected=0.172590
# predicted=0.599019, expected=0.751425
# predicted=0.485640, expected=0.958818
# predicted=0.426867, expected=0.484975
# Test MSE: 0.089
